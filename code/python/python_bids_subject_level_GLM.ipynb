# %%
# %matplotlib inline
# %load_ext nb_black

# %% [markdown]
# # First level analysis of a complete BIDS dataset from openneuro
#
# ---
#
# **Taken and adapted from the nilearn documentation**
#
# See the original [here]( ??? )
#
# ---
#
# Full step-by-step example of fitting a GLM to perform a first level analysis
# in an openneuro BIDS dataset. We demonstrate how BIDS derivatives can be
# exploited to perform a simple one subject analysis with minimal code.
# Details about the BIDS standard are available at http://bids.neuroimaging.io/.
# We also demonstrate how to download individual groups of files from the
# Openneuro s3 bucket.
#
# More specifically:
#
# 1. Download an fMRI BIDS dataset with derivatives from openneuro.
# 2. Extract first level model objects automatically from the BIDS dataset.
# 3. Demonstrate Quality assurance of Nistats estimation against available FSL.
#    estimation in the openneuro dataset.
# 4. Display contrast plot and uncorrected first level statistics table report.
#
#
#
# To run this example, you must launch IPython via ``ipython
# --matplotlib`` in a terminal, or use the Jupyter notebook.
#     :depth: 1

# %% [markdown]
# ## Fetch openneuro BIDS dataset
#
# We download one subject from the stopsignal task in the [ds000030](https://openneuro.org/datasets/ds000030/versions/1.0.0) V4 BIDS
# dataset available in openneuro.
#
#
# The preprocessed data described in are available at https://legacy.openfmri.org/dataset/ds000030/ and via Amazon Web Services S3 protocol at: s3://openneuro/ds000030/ds000030_R1.0.5/uncompressed/derivatives/
#
# TODO:
#
#     - download derivatives with datalad
#
# This dataset contains the necessary information to run a statistical analysis
# using Nilearn. The dataset also contains statistical results from a previous
# FSL analysis that we can employ for comparison with the Nilearn estimation.

# %%
# !datalad clone https://github.com/OpenNeuroDatasets/ds000030.git ../inputs/ds000030/
# Out:
# Clone attempt:   0%|              | 0.00/2.00 [00:00<?, ? Candidate locations/s]
# Enumerating: 0.00 Objects [00:00, ? Objects/s]
#
# Receiving:   0%|                             | 0.00/66.4k [00:00<?, ? Objects/s]
# Receiving:   3%|▌                   | 1.99k/66.4k [00:00<00:03, 17.2k Objects/s]
# Receiving:  12%|██▍                 | 7.97k/66.4k [00:00<00:02, 21.6k Objects/s]
# Receiving:  20%|████                | 13.3k/66.4k [00:00<00:02, 26.1k Objects/s]
# Receiving:  36%|███████▏            | 23.9k/66.4k [00:00<00:01, 33.4k Objects/s]
# Receiving:  51%|██████████▏         | 33.9k/66.4k [00:00<00:00, 41.3k Objects/s]
# Receiving:  70%|██████████████      | 46.5k/66.4k [00:00<00:00, 51.4k Objects/s]
# Receiving:  84%|████████████████▊   | 55.8k/66.4k [00:00<00:00, 59.0k Objects/s]
# Receiving:  97%|███████████████████▍| 64.4k/66.4k [00:01<00:00, 37.0k Objects/s]
#
# Resolving:   0%|                              | 0.00/11.7k [00:00<?, ? Deltas/s]
# [INFO   ] Scanning for unlocked files (this may take some time)
# [INFO   ] Remote origin not usable by git-annex; setting annex-ignore
# [INFO   ] access to 1 dataset sibling s3-PRIVATE not auto-enabled, enable with:
# | 		datalad siblings -d "/home/remi/github/openmr2021-dataviz-workshop-python/inputs/ds000030" enable -s s3-PRIVATE
# install(ok): /home/remi/github/openmr2021-dataviz-workshop-python/inputs/ds000030 (dataset)

# %%
# !datalad addurls s3://openneuro/ds000030/ds000030_R1.0.5/uncompressed/derivatives/
# Out:
# usage: datalad addurls [-h] [-d DATASET] [-t TYPE] [-x REGEXP] [-m FORMAT]
#                        [--message MESSAGE] [-n] [--fast]
#                        [--ifexists {overwrite|skip}] [--missing-value VALUE]
#                        [--nosave] [--version-urls] [-c PROC]
#                        URL-FILE URL-FORMAT FILENAME-FORMAT
# datalad addurls: error: the following arguments are required: URL-FORMAT, FILENAME-FORMAT

# %%
# !tree -d ../inputs/ds000030/
# Out:
# ../inputs/ds000030/
# ├── phenotype
# ├── sub-10159
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10171
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10189
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10193
# │   ├── anat
# │   ├── dwi
# │   └── func
# ├── sub-10206
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10217
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10225
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10227
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10228
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10235
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10249
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10269
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10271
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10273
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10274
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10280
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10290
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10292
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10299
# │   ├── beh
# │   └── func
# ├── sub-10304
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10316
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10321
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10325
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10329
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10339
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10340
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10345
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10347
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10356
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10361
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10365
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10376
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10377
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10388
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10428
# │   ├── beh
# │   └── func
# ├── sub-10429
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10438
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10440
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10448
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10455
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10460
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10471
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10478
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10487
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10492
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10501
# │   ├── beh
# │   └── func
# ├── sub-10506
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10517
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10523
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10524
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10525
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10527
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10530
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10557
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10565
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10570
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10575
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10624
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10629
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10631
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10638
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10668
# │   ├── anat
# │   ├── beh
# │   └── func
# ├── sub-10672
# │   ├── anat
# │   ├── beh
# │   └── func
# ├── sub-10674
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10678
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10680
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10686
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10692
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10696
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10697
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10704
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10707
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10708
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10719
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10724
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10746
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10762
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10779
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10785
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10788
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10844
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10855
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10871
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10877
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10882
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10891
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10893
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10912
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10934
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10940
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10948
# │   ├── anat
# │   ├── dwi
# │   └── func
# ├── sub-10949
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10958
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10963
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10968
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10971
# │   ├── beh
# │   └── func
# ├── sub-10975
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10977
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10987
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-10998
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11019
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11030
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11044
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11050
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11052
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11059
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11061
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11062
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11066
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11067
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11068
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11077
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11082
# │   ├── anat
# │   ├── dwi
# │   └── func
# ├── sub-11088
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11090
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11097
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11098
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11104
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11105
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11106
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11108
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11112
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11121
# │   ├── beh
# │   └── func
# ├── sub-11122
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11128
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11131
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11142
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11143
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11149
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-11156
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50004
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50005
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50006
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50007
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50008
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50010
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50013
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50014
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50015
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50016
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50020
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50021
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50022
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50023
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50025
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50027
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50029
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50032
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50033
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50034
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50035
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50036
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50038
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50043
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50047
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50048
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50049
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50050
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50051
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50052
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50053
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50054
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50055
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50056
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50058
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50059
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50060
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50061
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50064
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50066
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50067
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50069
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50073
# │   ├── anat
# │   ├── beh
# │   └── func
# ├── sub-50075
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50076
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50077
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50080
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50081
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50083
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-50085
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60001
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60005
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60006
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60008
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60010
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60011
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60012
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60014
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60015
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60016
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60017
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60020
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60021
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60022
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60028
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60030
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60033
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60036
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60037
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60038
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60042
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60043
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60045
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60046
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60048
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60049
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60051
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60052
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60053
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60055
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60056
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60057
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60060
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60062
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60065
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60066
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60068
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60070
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60072
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60073
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60074
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60076
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60077
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60078
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60079
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60080
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60084
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60087
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-60089
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70001
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70002
# │   ├── anat
# │   ├── dwi
# │   └── func
# ├── sub-70004
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70007
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70010
# │   ├── anat
# │   ├── dwi
# │   └── func
# ├── sub-70015
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70017
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70020
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70021
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70022
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70026
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70029
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70033
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70034
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70035
# │   ├── beh
# │   └── func
# ├── sub-70036
# │   ├── beh
# │   └── func
# ├── sub-70037
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70040
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70046
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70048
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70049
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70051
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70052
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70055
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70057
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70058
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70060
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70061
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70065
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70068
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70069
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70070
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70072
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70073
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70074
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70075
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70076
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70077
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70079
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70080
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70081
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# ├── sub-70083
# │   ├── anat
# │   ├── beh
# │   ├── dwi
# │   └── func
# └── sub-70086
#     ├── anat
#     ├── beh
#     ├── dwi
#     └── func
#
# 1339 directories

# %%
# !tree ../inputs/ds000030/sub-10159
# Out:
# ../inputs/ds000030/sub-10159
# ├── anat
# │   ├── sub-10159_T1w.json
# │   └── sub-10159_T1w.nii.gz -> ../../.git/annex/objects/KM/vk/MD5E-s11637742--75cab8005361c2504ba5a7f02ecbacd7.nii.gz/MD5E-s11637742--75cab8005361c2504ba5a7f02ecbacd7.nii.gz
# ├── beh
# │   ├── sub-10159_task-stopsignaltraining_beh.json
# │   └── sub-10159_task-stopsignaltraining_events.tsv
# ├── dwi
# │   ├── sub-10159_dwi.bval
# │   ├── sub-10159_dwi.bvec
# │   ├── sub-10159_dwi.json
# │   └── sub-10159_dwi.nii.gz -> ../../.git/annex/objects/Qm/mj/MD5E-s32000307--7b1e3890b74b9a9d96729ea967c69d95.nii.gz/MD5E-s32000307--7b1e3890b74b9a9d96729ea967c69d95.nii.gz
# └── func
#     ├── sub-10159_task-bart_bold.json
#     ├── sub-10159_task-bart_bold.nii.gz -> ../../.git/annex/objects/W1/V4/MD5E-s42078486--6ae43b435234a9f9179f95a216be9ba9.nii.gz/MD5E-s42078486--6ae43b435234a9f9179f95a216be9ba9.nii.gz
#     ├── sub-10159_task-bart_events.tsv
#     ├── sub-10159_task-rest_bold.json
#     ├── sub-10159_task-rest_bold.nii.gz -> ../../.git/annex/objects/Jj/MK/MD5E-s24052822--1e2cd9091e3f9b0d4475ce423a1d0840.nii.gz/MD5E-s24052822--1e2cd9091e3f9b0d4475ce423a1d0840.nii.gz
#     ├── sub-10159_task-scap_bold.json
#     ├── sub-10159_task-scap_bold.nii.gz -> ../../.git/annex/objects/qq/q3/MD5E-s45798387--127a45a8154c56685d0f2ba0bf294dee.nii.gz/MD5E-s45798387--127a45a8154c56685d0f2ba0bf294dee.nii.gz
#     ├── sub-10159_task-scap_events.tsv
#     ├── sub-10159_task-stopsignal_bold.json
#     ├── sub-10159_task-stopsignal_bold.nii.gz -> ../../.git/annex/objects/wW/K6/MD5E-s28934676--85331892f0072d30dc7ef6e43a527f11.nii.gz/MD5E-s28934676--85331892f0072d30dc7ef6e43a527f11.nii.gz
#     ├── sub-10159_task-stopsignal_events.tsv
#     ├── sub-10159_task-taskswitch_bold.json
#     ├── sub-10159_task-taskswitch_bold.nii.gz -> ../../.git/annex/objects/zM/Pq/MD5E-s32819511--e905861beab5a68166ee9c6e5ac39509.nii.gz/MD5E-s32819511--e905861beab5a68166ee9c6e5ac39509.nii.gz
#     └── sub-10159_task-taskswitch_events.tsv
#
# 4 directories, 22 files

# %%
from bids import BIDSLayout

data_folder = "../inputs/ds000030"
layout = BIDSLayout(data_folder)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-90a053574b38> in <module>
#       1 from bids import BIDSLayout
#       2 data_folder = "../inputs/ds000030"
# ----> 3 layout = BIDSLayout(data_folder)
#
# ~/.local/lib/python3.6/site-packages/bids/layout/layout.py in __init__(self, root, validate, absolute_paths, derivatives, config, sources, regex_search, database_path, reset_database, indexer, **indexer_kwargs)
#     153             if indexer is None:
#     154                 indexer = BIDSLayoutIndexer(validate=validate, **indexer_kwargs)
# --> 155             indexer(self)
#     156
#     157         # Add derivatives if any are found
#
# ~/.local/lib/python3.6/site-packages/bids/layout/index.py in __call__(self, layout)
#     109         self._index_dir(self._layout.root, self._config)
#     110         if self.index_metadata:
# --> 111             self._index_metadata()
#     112
#     113     @property
#
# ~/.local/lib/python3.6/site-packages/bids/layout/index.py in _index_metadata(self)
#     406                 images = self._layout.get(
#     407                     extension=['.nii', '.nii.gz'], suffix='dwi',
# --> 408                     return_type='filename', **file_ents)
#     409                 for img in images:
#     410                     create_association_pair(bf.path, img, 'IntendedFor',
#
# ~/.local/lib/python3.6/site-packages/bids/layout/layout.py in get(self, return_type, target, scope, regex_search, absolute_paths, invalid_filters, **filters)
#     655             # query = query.options(joinedload(BIDSFile.tags)
#     656             #                       .joinedload(Tag.entity))
# --> 657             results.extend(query.all())
#     658
#     659         # Convert to relative paths if needed
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/orm/query.py in all(self)
#    3344                 :ref:`faq_query_deduplicating`
#    3345         """
# -> 3346         return list(self)
#    3347
#    3348     @_generative(_no_clauseelement_condition)
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/orm/query.py in __iter__(self)
#    3506         if self._autoflush and not self._populate_existing:
#    3507             self.session._autoflush()
# -> 3508         return self._execute_and_instances(context)
#    3509
#    3510     def __str__(self):
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/orm/query.py in _execute_and_instances(self, querycontext)
#    3531         )
#    3532
# -> 3533         result = conn.execute(querycontext.statement, self._params)
#    3534         return loading.instances(querycontext.query, result, querycontext)
#    3535
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1512                 )
#    1513             else:
# -> 1514                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1515
#    1516         finally:
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
#    1276                     self.dialect.do_execute(
# -> 1277                         cursor, statement, parameters, context
#    1278                     )
#    1279
#
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Obtain FirstLevelModel objects automatically and fit arguments
# From the dataset directory we automatically obtain FirstLevelModel objects
# with their subject_id filled from the BIDS dataset. Moreover we obtain,
# for each model, the list of run images and their respective events and
# confound regressors. Those are inferred from the confounds.tsv files
# available in the BIDS dataset.
# To get the first level models we have to specify the dataset directory,
# the task_label and the space_label as specified in the file names.
# We also have to provide the folder with the desired derivatives, that in this
# case were produced by the fmriprep BIDS app.

# %%
from nilearn.glm.first_level import first_level_from_bids
task_label = 'stopsignal'
space_label = 'MNI152NLin2009cAsym'
derivatives_folder = 'derivatives/fmriprep'
models, models_run_imgs, models_events, models_confounds = \
    first_level_from_bids(data_dir, task_label, space_label,
                          smoothing_fwhm=5.0,
                          derivatives_folder=derivatives_folder)

# %% [markdown]
# Access the model and model arguments of the subject and process events.

# %%
model, imgs, events, confounds = (
    models[0], models_run_imgs[0], models_events[0], models_confounds[0])
subject = 'sub-' + model.subject_label

import os
from nilearn._utils.glm import get_design_from_fslmat
fsl_design_matrix_path = os.path.join(
    data_dir, 'derivatives', 'task', subject, 'stopsignal.feat', 'design.mat')
design_matrix = get_design_from_fslmat(
    fsl_design_matrix_path, column_names=None)

# %% [markdown]
# We identify the columns of the Go and StopSuccess conditions of the
# design matrix inferred from the FSL file, to use them later for contrast
# definition.

# %%
design_columns = ['cond_%02d' % i for i in range(len(design_matrix.columns))]
design_columns[0] = 'Go'
design_columns[4] = 'StopSuccess'
design_matrix.columns = design_columns

# %% [markdown]
# ## First level model estimation (one subject)
# We fit the first level model for one subject.

# %%
model.fit(imgs, design_matrices=[design_matrix])

# %% [markdown]
# Then we compute the StopSuccess - Go contrast. We can use the column names
# of the design matrix.

# %%
z_map = model.compute_contrast('StopSuccess - Go')

# %% [markdown]
# We show the agreement between the Nilearn estimation and the FSL estimation
# available in the dataset.

# %%
import nibabel as nib
fsl_z_map = nib.load(
    os.path.join(data_dir, 'derivatives', 'task', subject, 'stopsignal.feat',
                 'stats', 'zstat12.nii.gz'))

from nilearn import plotting
import matplotlib.pyplot as plt
from scipy.stats import norm
plotting.plot_glass_brain(z_map, colorbar=True, threshold=norm.isf(0.001),
                          title='Nilearn Z map of "StopSuccess - Go" (unc p<0.001)',
                          plot_abs=False, display_mode='ortho')
plotting.plot_glass_brain(fsl_z_map, colorbar=True, threshold=norm.isf(0.001),
                          title='FSL Z map of "StopSuccess - Go" (unc p<0.001)',
                          plot_abs=False, display_mode='ortho')
plt.show()

from nilearn.plotting import plot_img_comparison
plot_img_comparison([z_map], [fsl_z_map], model.masker_,
                    ref_label='Nilearn', src_label='FSL')
plt.show()

# %% [markdown]
# ## Simple statistical report of thresholded contrast
# We display the contrast plot and table with cluster information

# %%
from nilearn.plotting import plot_contrast_matrix
plot_contrast_matrix('StopSuccess - Go', design_matrix)
plotting.plot_glass_brain(z_map, colorbar=True, threshold=norm.isf(0.001),
                          plot_abs=False, display_mode='z',
                          figure=plt.figure(figsize=(4, 4)))
plt.show()

# %% [markdown]
# We can get a latex table from a Pandas Dataframe for display and publication
# purposes

# %%
from nilearn.reporting import get_clusters_table
print(get_clusters_table(z_map, norm.isf(0.001), 10).to_latex())

# %% [markdown]
# ## Generating a report
# Using the computed FirstLevelModel and contrast information,
# we can quickly create a summary report.

# %%
from nilearn.reporting import make_glm_report

report = make_glm_report(model=model,
                         contrasts='StopSuccess - Go',
                         )

# %% [markdown]
# We have several ways to access the report:

# %%
# report  # This report can be viewed in a notebook
# report.save_as_html('report.html')
# report.open_in_browser()
